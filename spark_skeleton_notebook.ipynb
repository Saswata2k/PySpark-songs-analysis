# %%
import os
from datetime import datetime
import pyspark.sql.functions as F
import pyspark.sql.types as T
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("sparkify_etl").config("spark.sql.session.timeZone", "UTC")\
                            .master("local").getOrCreate()

# %% [markdown]
# ## First, Let us check the schema for log data files

# %%
file_path = os.path.join("data","log-data")
data_log = spark.read.json(file_path)
data_log = data_log.where(F.col("page")=="NextSong")
data_log.printSchema()
data_log.limit(2).toPandas()

# Observation
# 1. itemInSession can be integer
# 2. timestamp column can be datetime
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: double (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)
#         artist       auth firstName gender  itemInSession lastName     length  \
# 0     Harmonia  Logged In      Ryan      M              0    Smith  655.77751
# 1  The Prodigy  Logged In      Ryan      M              1    Smith  260.07465
#
#   level                            location method      page  registration  \
# 0  free  San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 1  free  San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
#
#    sessionId             song  status             ts  \
# 0        583    Sehr kosmisch     200  1542241826796
# 1        583  The Big Gundown     200  1542242481796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 1  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26

# %% [markdown]
# ## We will check schema and explore song data files next

# %%
file_path = os.path.join("data","song_data","*","*","*")
data_song = spark.read.json(file_path)
data_song.printSchema()

# Since there's one record per song file, we don't need to use limit
data_song.limit(5).toPandas()

# Observation
#lat,long can be double
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_latitude: double (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_longitude: double (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- num_songs: long (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: long (nullable = true)
#             artist_id  artist_latitude    artist_location  artist_longitude  \
# 0  ARDR4AC1187FB371A1              NaN                                  NaN
# 1  AREBBGV1187FB523D2              NaN        Houston, TX               NaN
# 2  ARMAC4T1187FB3FA4C         40.82624  Morris Plains, NJ         -74.47995
# 3  ARPBNLO1187FB3D52F         40.71455       New York, NY         -74.00712
# 4  ARDNS031187B9924F0         32.67828            Georgia         -83.22295
#
#                                          artist_name   duration  num_songs  \
# 0  Montserrat Caballé;Placido Domingo;Vicente Sar...  511.16363          1
# 1       Mike Jones (Featuring CJ_ Mello & Lil' Bran)  173.66159          1
# 2                          The Dillinger Escape Plan  207.77751          1
# 3                                           Tiny Tim   43.36281          1
# 4                                         Tim Wilson  186.48771          1
#
#               song_id                                              title  year
# 0  SOBAYLL12A8C138AF9                    Sono andati? Fingevo di dormire     0
# 1  SOOLYAZ12A6701F4A6                    Laws Patrolling (Album Version)     0
# 2  SOBBUGU12A8C13E95D                    Setting Fire to Sleeping Giants  2004
# 3  SOAOIBZ12AB01815BE  I Hold Your Hand In Mine [Live At Royal Albert...  2000
# 4  SONYPOM12A8C13B2D7  I Think My Wife Is Running Around On Me (Taco ...  2005

# %% [markdown]
# ## Let's first create the user table

# %%
#user_id, first_name, last_name, gender, level

df_user = data_log.select("userId","firstName","lastName","gender","level")

# User sql expression to cast specific columns
df_user = df_user.withColumn("userId",F.expr("cast(userId as long) userId"))
df_user.printSchema()
df_user.limit(5).toPandas()
# Out:
# root
#  |-- userId: long (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- level: string (nullable = true)
#    userId firstName  lastName gender level
# 0      26      Ryan     Smith      M  free
# 1      26      Ryan     Smith      M  free
# 2      26      Ryan     Smith      M  free
# 3      61    Samuel  Gonzalez      M  free
# 4      80     Tegan    Levine      F  paid

# %% [markdown]
# ## Next we will create songs table

# %%
#song_id, title, artist_id, year, duration

df_song = data_song.select("song_id","title","artist_id","year","duration")
df_song = df_song.withColumn("year",F.col("year").cast(T.IntegerType()))
df_song.printSchema()
df_song.toPandas()
# Out:
# root
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-
# 45  AREVWGE1187B9B890A     0  282.43546
# 46  ARNTLGG11E2835DDB9     0  266.39628
# 47  AR5KOSW1187FB35FF4     0  269.58322
# 48  ARGIWFO1187B9B55B7     0  225.09669
# 49  AR1ZHYZ1187FB3C717     0  599.24853
# 50  ARD0S291187B9B7BF5     0  114.78159
# 51  ARKRRTF1187B9984DA     0  177.47546
# 52  ARKULSX1187FB45F84     0  424.12363
# 53  ARULZCI1241B9C8611     0  335.51628
# 54  ARJIE2Y1187B994AB7     0  152.92036
# 55  AR8ZCNI1187B9A069B  1984  269.81832
# 56  AR7SMBG1187B9B9066     0  218.38322
# 57  ARVBRGZ1187FB4675A  2004  290.55955
# 58  ARD7TVE1187B99BFB1     0  259.44771
# 59  AR8IEZO1187B99055E  2008  149.86404
# 60  AROGWRA122988FEE45     0  243.82649
# 61  AR62SOJ1187FB47BB5  2005  337.68444
# 62  AR051KA1187B98B2FF     0  261.51138
# 63  ARYKCQI1187FB3B18F  2004  290.29832
# 64  ARNPAGP1241B9C7FD4     0  165.69424
# 65  ARHHO3O1187B989413     0  191.84281
# 66  AR7ZKHQ1187B98DD73  1993  270.60200
# 67  ARXR32B1187FB57099  2007  209.60608
# 68  ARNTLGG11E2835DDB9     0  338.31138
# 69  ARL7K851187B99ACD2     0  226.35057
# 70  AR558FS1187FB45658  2003   75.67628
#
# [71 rows x 5 columns]

# %% [markdown]
# ## Artist Table will be created from song data as well

# %%
# artist_id, name, location, lattitude, longitude

df_artist = data_song.select("artist_id","artist_name","artist_location","artist_latitude","artist_longitude")
df_artist = df_artist.withColumn("artist_latitude",F.col("artist_latitude").cast(T.DecimalType()))
df_artist = df_artist.withColumn("artist_longitude",F.col("artist_longitude").cast(T.DecimalType()))
df_artist.printSchema()
df_artist.toPandas()
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_latitude: decimal(10,0) (nullable = true)
#  |-- artist_longitude: decimal(10,0) (nullable = true)
#              artist_id                                        artist_name  \
# 0   ARDR4AC1187FB371A1  Montserrat Caballé;Placido Domingo;Vicente Sar...
# 1   AREBBGV1187FB523D2       Mike Jones (Featuring CJ_ Mello & Lil' Bran)
# 2   ARMAC4T1187FB3FA4C                          The Dillinger Escape Plan
# 3   ARPBNLO1187FB3D52F                                           Tiny Tim
# 4   ARDNS031187B9924F0                                         Tim Wilson
# 5   ARNF6401187FB57032                                  Sophie B. Hawkins
# 6   ARLTWXK1187FB5A3F8                                        King Curtis
# 7   ARPFHN61187FB575F6                                        Lupe Fiasco
# 8   ARI2JSK1187FB496EF                           Nick Ingman;Gavyn Wright
# 9   AR0RCMP1187FB3F427                                   Billie Jo Spears
# 10  AROUOZZ1187B9ABE51                                        Willie Bobo
# 11  AR9AWNF1187B9AB0B4                       Kenny G featuring Daryl Hall
# 12  AR47JEX1187B995D81                                       SUE THOMPSON
# 13  ARKFYS91187B98E58F                              Jeff And Sheri Easter
# 14  AR10USD1187B99F3F1                              Tweeterfriendly Music
# 15  ARB29H41187B98F0EF                                      Terry Callier
# 13                                           None             None
# 14    Burlington, Ontario, Canada            None             None
# 15                        Chicago              42              -88
# 16                    Mineola, AR              34              -94
# 17                California - SF              38             -122
# 18                Gainesville, FL            None             None
# 19                        Denmark              56               10
# 20              Beverly Hills, CA            None             None
# 21       Toronto, Ontario, Canada              44              -79
# 22                   Pennsylvania              41              -78
# 23                    Orlando, FL              29              -81
# 24                 Nashville, TN.              36              -87
# 25                     Newark, NJ              41              -74
# 26                California - SF              38             -122
# 27                 Zagreb Croatia              46               16
# 28                     Queens, NY              41              -74
# 29                 North Carolina              35              -80
# ..                            ...             ...              ...
# 41                     Washington              39              -77
# 42                         Panama               8              -80
# 43                California - LA            None             None
# 44                 Hamilton, Ohio            None             None
# 45                      Noci (BA)             -13              -42
# 46                                           None             None
# 47                      Dubai UAE              50               15
# 48                                           None             None
# 49                                           None             None
# 50                           Ohio            None             None
# 51                                           None             None
# 52                           Utah              39             -112
# 53                                           None             None
# 54                                           None             None
# 55                                           None             None
# 56                                           None             None
# 57                                           None             None
# 58                California - LA            None             None
# 59                                           None             None
# 60                                           None             None
# 61                                           None             None
# 62                                           None             None
# 63                                           None             None
# 64                                           None             None
# 65                                           None             None
# 66                                           None             None
# 67                                           None             None
# 68                                           None             None
# 69                                           None             None
# 70                                           None             None
#
# [71 rows x 5 columns]

# %% [markdown]
# ## Our next dimension Table would be of Time where we'd split "ts" timestamp col further to      granular level

# %%
# start_time, hour, day, week, month, year, weekday

df_time = data_log.select("ts")
time_format = "yyyy-MM-dd' 'HH:mm:ss.SSS"


#func = F.udf("start_time")
df_time = df_time.withColumn("start_time", \
                             F.to_utc_timestamp(F.from_unixtime(F.col("ts")/1000,format=time_format),tz="UTC"))
df_time = df_time.withColumn("hour",F.hour(F.col("start_time")))
df_time = df_time.withColumn("day",F.dayofmonth(F.col("start_time")))
df_time = df_time.withColumn("week",F.weekofyear(F.col("start_time")))
df_time = df_time.withColumn("month",F.month(F.col("start_time")))
df_time = df_time.withColumn("year",F.year(F.col("start_time")))
df_time = df_time.withColumn("weekday",F.dayofweek(F.col("start_time")))

df_time.printSchema()
df_time.limit(2).toPandas()
# Out:
# root
#  |-- ts: long (nullable = true)
#  |-- start_time: timestamp (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- week: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- weekday: integer (nullable = true)
#               ts          start_time  hour  day  week  month  year  weekday
# 0  1542241826796 2018-11-15 00:30:26     0   15    46     11  2018        5
# 1  1542242481796 2018-11-15 00:41:21     0   15    46     11  2018        5

# %% [markdown]
# ## Now that we've created all DIMENSIONAL tables let us proceed for the FACTS table creation
#
# ### In order to create facts table, we have to perform joins
#
# #### SQL syntax is better for longer join queries, but the same can be replicated using spark dataframe operations

# %%
# songplay_id, start_time, user_id, level, song_id, artist_id, session_id, location, user_agent
#TODO : Partition by specific keys before uploading to S3 as parquet

df_song_play = data_song.join(data_log,data_song.title==data_log.song, how="inner").\
                    select("userId","level","song_id","artist_id","sessionId","location","userAgent")
df_song_play.printSchema()
df_song_play.limit(2).toPandas()
# Out:
# root
#  |-- userId: string (nullable = true)
#  |-- level: string (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- artist_id: string (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- location: string (nullable = true)
#  |-- userAgent: string (nullable = true)
#   userId level             song_id           artist_id  sessionId  \
# 0     15  paid  SOZCTXZ12AB0182364  AR5KOSW1187FB35FF4        818
# 1     10  free  SOGDBUF12A8C140FAA  AR558FS1187FB45658        484
#
#                                        location  \
# 0            Chicago-Naperville-Elgin, IL-IN-WI
# 1  Washington-Arlington-Alexandria, DC-VA-MD-WV
#
#                                            userAgent
# 0  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 1  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...

# %%
# First let us define some views
data_log.createOrReplaceTempView("t_log")
data_song.createOrReplaceTempView("t_song")
df_time.createOrReplaceTempView("t_time")

df_song_play = spark.sql("select t_time.start_time, t_log.userId, t_log.level, \
                          t_song.song_id, t_song.artist_id, t_log.sessionId, \
                          t_log.location, t_log.userAgent \
                          from t_log  \
                          inner join t_song \
                          on t_log.song=t_song.title \
                          inner join t_time \
                          on t_time.ts = t_log.ts \
                          where t_log.artist = t_song.artist_name \
                          and song_id is not null \
                          ")
df_song_play.limit(2).toPandas()
# Out:
#            start_time userId level             song_id           artist_id  \
# 0 2018-11-21 21:56:47     15  paid  SOZCTXZ12AB0182364  AR5KOSW1187FB35FF4
#
#    sessionId                            location  \
# 0        818  Chicago-Naperville-Elgin, IL-IN-WI
#
#                                            userAgent
# 0  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...

# %%
df_song_play.write.mode("overwrite").parquet("data/output.parquet")

# %%
df = spark.read.parquet('data/time_parquet.parquet')
df.toPandas()
# Out:
#                                   artist       auth firstName gender  \
# 0                               Harmonia  Logged In      Ryan      M
# 1                            The Prodigy  Logged In      Ryan      M
# 2                                  Train  Logged In      Ryan      M
# 3                            Sony Wonder  Logged In    Samuel      M
# 4                              Van Halen  Logged In     Tegan      F
# 5                              Magic Sam  Logged In     Tegan      F
# 6     Edward Sharpe & The Magnetic Zeros  Logged In     Tegan      F
# 7              Usher featuring will.i.am  Logged In     Tegan      F
# 8                            Helen Reddy  Logged In     Tegan      F
# 9                           Taylor Swift  Logged In     Tegan      F
# 10                             Sean Paul  Logged In     Tegan      F
# 11                           Soundgarden  Logged In      Lily      F
# 12                           The Killers  Logged In     Tegan      F
# 13                         Amy Winehouse  Logged In      Lily      F
# 14                        Steve Anderson  Logged In      Lily      F
# 15                            Rob Zombie  Logged In      Lily      F
# 16                    Deadmau5 & Kaskade  Logged In      Lily      F
# 17                          Shania Twain  Logged In      Ryan      M
# 18                        Los Campesinos  Logged In      Ryan      M
# 19                              Ill Nino  Logged In     Chloe      F
# 20                                 Mia X  Logged In     Chloe      F
# 21              Rage Against The Machine  Logged In     Chloe      F
# 22                             Asia 2001  Logged In     Chloe      F
# 23                                  Muse  Logged In     Chloe      F
# 24                          Rise Against  Logged In     Chloe      F
# 25                          Modest Mouse  Logged In  Mohammad      M
# 26                          Marc Anthony  Logged In     Chloe      F
# 27                        Regina Spektor  Logged In     Chloe      F
# 28                              Nina Sky  Logged In     Tegan      F
# 29                      Five Iron Frenzy  Logged In     Avery      F
# ...                                  ...        ...       ...    ...
# 6790         Jason Mraz & Colbie Caillat  Logged In     Chloe      F
# 6791                            R. Kelly  Logged In  Anabelle      F
# 6792                     Jacky Terrasson  Logged In    Marina      F
# 6793                          Papa Roach  Logged In  Theodore      M
# 6794                      Burt Bacharach  Logged In  Theodore      M
# 6795                             Floetry  Logged In     Chloe      F
# 6796                           The Rakes  Logged In     Chloe      F
# 6797                       Dwight Yoakam  Logged In     Chloe      F
# 6798                                Ween  Logged In     Chloe      F
# 6799                     CafÃÂ© Quijano  Logged In     Chloe      F
# 6800                        Parov Stelar  Logged In     Chloe      F
# 6801                         Bryan Adams  Logged In     Tegan      F
# 6802                         KT Tunstall  Logged In     Tegan      F
# 6803                        Technicolour  Logged In     Tegan      F
# 6804                           The Dears  Logged In     Tegan      F
# 6805                             Go West  Logged In     Tegan      F
# 6806                            Gondwana  Logged In    Jordan      F
# 6807                     Ella Fitzgerald  Logged In    Jordan      F
# 6808        Creedence Clearwater Revival  Logged In    Jordan      F
# 6809                             Des'ree  Logged In    Kaylee      F
# 6810                             Mr Oizo  Logged In    Kaylee      F
# 6811                          Tamba Trio  Logged In    Kaylee      F
# 6812                      The Mars Volta  Logged In    Kaylee      F
# 6813                   Infected Mushroom  Logged In    Kaylee      F
# 6814          Blue October / Imogen Heap  Logged In    Kaylee      F
# 6815                           Girl Talk  Logged In    Kaylee      F
# 6816                     Black Eyed Peas  Logged In    Sylvie      F
# 6817                        Fall Out Boy  Logged In      Ryan      M
# 6818                              M.I.A.  Logged In      Ryan      M
# 6819                            Survivor  Logged In    Jayden      M
#
#       itemInSession   lastName     length level  \
# 0                 0      Smith  655.77751  free
# 1                 1      Smith  260.07465  free
# 2                 2      Smith  205.45261  free
# 3                 0   Gonzalez  218.06975  free
# 4                 2     Levine  289.38404  paid
# 5                 3     Levine  132.04853  paid
# 6                 4     Levine  306.31138  paid
# 7                 5     Levine  395.72853  paid
# 8                 7     Levine  176.50893  paid
# 9                 8     Levine  201.06404  paid
# 10                9     Levine  245.34159  paid
# 11                0       Koch  272.19546  paid
# 12               10     Levine  360.75057  paid
# 13                1       Koch  165.11955  paid
# 14                2       Koch  265.06404  paid
# 15                3       Koch  220.13342  paid
# 16                4       Koch  595.56526  paid
# 17                0      Smith  213.70730  free
# 18                1      Smith  138.10893  free
# 19                1     Cuevas  188.91710  paid
# 20                2     Cuevas  236.09424  paid
# 21                3     Cuevas  314.40934  paid
# 22                4     Cuevas  150.30812  paid
# 23                5     Cuevas  228.93669  paid
# 24                6     Cuevas  221.17832  paid
# 25                3  Rodriguez  259.47383  free
# 26                7     Cuevas  314.43546  paid
# 27                8     Cuevas  191.08526  paid
# 28                0     Levine  101.92934  paid
# 29                0    Watkins  236.09424  paid
# ...             ...        ...        ...   ...
# 6790              0       Roth  189.62240  free
# 6791              1    Simpson  234.39628  free
# 6792              0     Sutton  342.75220  free
# 6793              0     Harris  202.18730  free
# 6794              1     Harris  156.96934  free
# 6795              1     Cuevas  254.48444  paid
# 6796              2     Cuevas  225.22730  paid
# 6797              3     Cuevas  239.30730  paid
# 6798              4     Cuevas  228.10077  paid
# 6799              5     Cuevas  197.32853  paid
# 6800              1       Roth  203.65016  free
# 6801              1     Levine  166.29506  paid
# 6802              2     Levine  192.31302  paid
# 6803              3     Levine  235.12771  paid
# 6804              4     Levine  289.95873  paid
# 6805              5     Levine  259.49995  paid
# 6806              0      Hicks  262.58240  free
# 6807              1      Hicks  427.15383  free
# 6808              2      Hicks  184.73751  free
# 6809              1    Summers  246.30812  free
# 6810              3    Summers  144.03873  free
# 6811              4    Summers  177.18812  free
# 6812              5    Summers  380.42077  free
# 6813              6    Summers  440.26730  free
# 6814              7    Summers  241.39710  free
# 6815              8    Summers  160.15628  free
# 6816              0       Cruz  214.93506  free
# 6817              1      Smith  200.72444  free
# 6818              2      Smith  233.71710  free
# 6819              0        Fox  245.36771  free
#
#                                           location method  ...             ts  \
# 0               San Jose-Sunnyvale-Santa Clara, CA    PUT  ...  1542241826796
# 1               San Jose-Sunnyvale-Santa Clara, CA    PUT  ...  1542242481796
# 2               San Jose-Sunnyvale-Santa Clara, CA    PUT  ...  1542242741796
# 3             Houston-The Woodlands-Sugar Land, TX    PUT  ...  1542253449796
# 4                      Portland-South Portland, ME    PUT  ...  1542260935796
# 5                      Portland-South Portland, ME    PUT  ...  1542261224796
# 6                      Portland-South Portland, ME    PUT  ...  1542261356796
# 7                      Portland-South Portland, ME    PUT  ...  1542261662796
# 8                      Portland-South Portland, ME    PUT  ...  1542262057796
# 9                      Portland-South Portland, ME    PUT  ...  1542262233796
# 10                     Portland-South Portland, ME    PUT  ...  1542262434796
# 11              Chicago-Naperville-Elgin, IL-IN-WI    PUT  ...  1542262456796
# 12                     Portland-South Portland, ME    PUT  ...  1542262679796
# 13              Chicago-Naperville-Elgin, IL-IN-WI    PUT  ...  1542262728796
# 14              Chicago-Naperville-Elgin, IL-IN-WI    PUT  ...  1542262893796
# 15              Chicago-Naperville-Elgin, IL-IN-WI    PUT  ...  1542263158796
# 16              Chicago-Naperville-Elgin, IL-IN-WI    PUT  ...  1542263378796
# 17              San Jose-Sunnyvale-Santa Clara, CA    PUT  ...  1542265716796
# 18              San Jose-Sunnyvale-Santa Clara, CA    PUT  ...  1542265929796
# 19               San Francisco-Oakland-Hayward, CA    PUT  ...  1542266927796
# 20               San Francisco-Oakland-Hayward, CA    PUT  ...  1542267115796
# 21               San Francisco-Oakland-Hayward, CA    PUT  ...  1542267351796
# 22               San Francisco-Oakland-Hayward, CA    PUT  ...  1542267665796
# 23               San Francisco-Oakland-Hayward, CA    PUT  ...  1542267815796
# 24               San Francisco-Oakland-Hayward, CA    PUT  ...  1542268043796
# 25         Sacramento--Roseville--Arden-Arcade, CA    PUT  ...  1542268205796
# 26               San Francisco-Oakland-Hayward, CA    PUT  ...  1542268264796
# 27               San Francisco-Oakland-Hayward, CA    PUT  ...  1542268578796
# 28                     Portland-South Portland, ME    PUT  ...  1542274783796
# 29              San Jose-Sunnyvale-Santa Clara, CA    PUT  ...  1542275422796
# ...                                            ...    ...  ...            ...
# 6790              Indianapolis-Carmel-Anderson, IN    PUT  ...  1543135208796
# 6791   Philadelphia-Camden-Wilmington, PA-NJ-DE-MD    PUT  ...  1543145305796
# 6792                                   Salinas, CA    PUT  ...  1543154200796
# 6793                                 Red Bluff, CA    PUT  ...  1543155228796
# 6794                                 Red Bluff, CA    PUT  ...  1543155430796
# 6795             San Francisco-Oakland-Hayward, CA    PUT  ...  1543161985796
# 6796             San Francisco-Oakland-Hayward, CA    PUT  ...  1543162239796
# 6797             San Francisco-Oakland-Hayward, CA    PUT  ...  1543162464796
# 6798             San Francisco-Oakland-Hayward, CA    PUT  ...  1543162703796
# 6799             San Francisco-Oakland-Hayward, CA    PUT  ...  1543162931796
# 6800              Indianapolis-Carmel-Anderson, IN    PUT  ...  1543166945796
# 6801                   Portland-South Portland, ME    PUT  ...  1543170092796
# 6802                   Portland-South Portland, ME    PUT  ...  1543170258796
# 6803                   Portland-South Portland, ME    PUT  ...  1543170450796
# 6804                   Portland-South Portland, ME    PUT  ...  1543170685796
# 6805                   Portland-South Portland, ME    PUT  ...  1543170974796
# 6806                                   Salinas, CA    PUT  ...  1543189690796
# 6807                                   Salinas, CA    PUT  ...  1543189952796
# 6808                                   Salinas, CA    PUT  ...  1543190379796
# 6809                   Phoenix-Mesa-Scottsdale, AZ    PUT  ...  1541106106796
# 6810                   Phoenix-Mesa-Scottsdale, AZ    PUT  ...  1541106352796
# 6811                   Phoenix-Mesa-Scottsdale, AZ    PUT  ...  1541106496796
# 6812                   Phoenix-Mesa-Scottsdale, AZ    PUT  ...  1541106673796
# 6813                   Phoenix-Mesa-Scottsdale, AZ    PUT  ...  1541107053796
# 6814                   Phoenix-Mesa-Scottsdale, AZ    PUT  ...  1541107493796
# 6815                   Phoenix-Mesa-Scottsdale, AZ    PUT  ...  1541107734796
# 6816  Washington-Arlington-Alexandria, DC-VA-MD-WV    PUT  ...  1541108520796
# 6817            San Jose-Sunnyvale-Santa Clara, CA    PUT  ...  1541109125796
# 6818            San Jose-Sunnyvale-Santa Clara, CA    PUT  ...  1541109325796
# 6819                      New Orleans-Metairie, LA    PUT  ...  1541110994796
#
#                                               userAgent  userId  \
# 0     "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 1     "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 2     "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 3     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      61
# 4     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 5     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 6     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 7     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 8     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 9     "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 10    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 11    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      15
# 12    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 13    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      15
# 14    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      15
# 15    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      15
# 16    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      15
# 17    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 18    "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 19    Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 20    Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 21    Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 22    Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 23    Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 24    Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 25    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      88
# 26    Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 27    Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 28    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 29    Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...      30
# ...                                                 ...     ...
# 6790  Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20...      78
# 6791  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      69
# 6792  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      48
# 6793  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...      14
# 6794  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...      14
# 6795  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 6796  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 6797  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 6798  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 6799  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...      49
# 6800  Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20...      78
# 6801  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 6802  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 6803  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 6804  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 6805  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      80
# 6806  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      37
# 6807  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      37
# 6808  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      37
# 6809  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6810  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6811  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6812  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6813  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6814  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6815  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...       8
# 6816  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...      10
# 6817  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 6818  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...      26
# 6819  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     101
#
#               start_time  hour  day week month  year  weekday
# 0    2018-11-15 00:30:26     6   15   46    11  2018        5
# 1    2018-11-15 00:41:21     6   15   46    11  2018        5
# 2    2018-11-15 00:45:41     6   15   46    11  2018        5
# 3    2018-11-15 03:44:09     9   15   46    11  2018        5
# 4    2018-11-15 05:48:55    11   15   46    11  2018        5
# 5    2018-11-15 05:53:44    11   15   46    11  2018        5
# 6    2018-11-15 05:55:56    11   15   46    11  2018        5
# 7    2018-11-15 06:01:02    11   15   46    11  2018        5
# 8    2018-11-15 06:07:37    11   15   46    11  2018        5
# 9    2018-11-15 06:10:33    11   15   46    11  2018        5
# 10   2018-11-15 06:13:54    11   15   46    11  2018        5
# 11   2018-11-15 06:14:16    11   15   46    11  2018        5
